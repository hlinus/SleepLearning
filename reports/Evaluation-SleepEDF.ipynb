# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys
import matplotlib.pyplot as plt
root_dir = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..'))
sys.path.insert(0, root_dir)
from sleeplearning.lib.evaluation import Evaluation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'results/SleepEDF/CV'
e = Evaluation(path)
# Out:
# model Proposed Approach
# config: Fpz-Cz
# runs: CV
# config: Pz-Cz
# runs: CV
# model Supratak et al. 2017
# config: Fpz-Cz
# runs: CV
# config: Pz-Cz
# runs: CV

# %%
e.bar()

# %%
e.cm()

# %%
e.table()
