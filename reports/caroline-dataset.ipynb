# %% [markdown]
# # We analyze the problem of classifying sleep phases

# %% [markdown]
# ### (1) We start by importing necessary pre-installed packages

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# ### (2) We import our 'sleeplearning' library

# %%
root_dir = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..'))
sys.path.insert(0, root_dir)
from sleeplearning.lib.base import SleepLearning
from sleeplearning.lib.loaders.carofile import Carofile
from sleeplearning.lib.visualize import Visualize
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### (3) We load all the mat files from a folder with verbose output for the first file

# %%
caro_subjects = []
for i, filename in enumerate(glob.glob(root_dir + '/data/raw/caroline/*.mat')):
    s = Carofile(filename, verbose = (i == 0))
    caro_subjects.append(s)
# Out:
# EEG: cutting  18.644 seconds at the end
# EOGR: cutting  18.644 seconds at the end
# EOGL: cutting  18.644 seconds at the end
# EMG: cutting  18.644 seconds at the end

# %% [markdown]
# ### (4) We plot some overall statistics

# %%
vcaro = Visualize(caro_subjects)
vcaro.class_distribution()

# %%
vcaro.transition_distribution()

# %% [markdown]
# ### (5) We visualize the data of a single subject

# %%
d01 = caro_subjects[0]
vd01 = Visualize([d01])

# %%
vd01.epoch(epoch_index=15, channel='EMG')

# %%
vd01.psd(channel='EMG', sleep_phases=[0,1,2,3,5,6])

# %%
vd01.qualitative_analysis(channel='EOGL', from_epoch=250, to_epoch=350)
